# %% [markdown]
# # Testing
#
# In order to test the sensitivity of a LDM we have to look at the input data of the algorithm. We can divide the input data into two categories:
#
# ## Sensor Data
# Sensors have different properties which can be classified into
#  -
#  - Resolution (temporal, spatial)
#    - Temporal: How often does the sensor measure the data? (e.g. every 10 minutes)
#    - Spatial:
#  - Sensitivity
#    - How sensitive is the sensor to changes in the environment? (for which 0.1 pascale)
#  - Accuracy: (how big is the maximum difference of a measurements from the true value)
#  - Precision: (variability of the measurements around the true value)
#
#  - Noise? (from events)
#
#
# ## Model
#    - Spatial: How many sensors are used to measure the data? (e.g. 10 sensors in the network)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("cool")
# Out:
# cool
